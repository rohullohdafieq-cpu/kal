# %% [markdown]
# ## Matriks Vector
#
# ![tugas1](tugas1.jpg)

# %% [markdown]
# ![tugas2](tugas2.jpg)

# %% [markdown]
# ![tugas3](tugas3.jpg)

# %% [markdown]
# ![tugas4](tugas4.jpg)

# %% [markdown]
# ![tugas5](tugas5.jpg)
